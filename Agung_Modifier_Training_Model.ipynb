# %% [markdown]
# # **Preprocess Data and Create Labels and Features**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from keras.utils import to_categorical
import numpy as np
import os
import cv2 as cv
import mediapipe as mp
from matplotlib import pyplot as plt
from mediapipe.python.solutions.pose import PoseLandmark

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, Bidirectional
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model

from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_multilabel_classification
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns

# %%
DATA_PATH = os.path.join('El_Agung')

actions = np.array(["Kanan", "Maju", "Stop", "Mundur", "Kiri"
                    ])
sequence_length = 30

# %%
label_map = {label: num for num, label in enumerate(actions)}
label_map

sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(
                sequence), "{}-norm.npy".format(frame_num)))

            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

np.array(sequences).shape
# Out:
# (150, 30, 108)

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (105, 30, 108)
# (45, 30, 108)
# (105, 5)
# (45, 5)

# %% [markdown]
# # **Build and Train LSTM Neural Network**

# %%
checkpoint = ModelCheckpoint('agung.keras', monitor='categorical_accuracy', verbose=1,
                             mode='max', save_best_only=True, save_weights_only=False, save_freq='epoch')

# %%
model = Sequential()

model.add(TimeDistributed(
    Dense(units=128, activation='tanh'), input_shape=(30, 108)))
model.add(LSTM(128, return_sequences=True, activation='tanh'))
model.add(Dropout(0.5))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(Dropout(0.5))
model.add(LSTM(32, return_sequences=False, activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(actions.shape[0], activation='softmax'))

model.summary()
# Out:
# d:\Castano\sign-language-lstm-master\.venv\lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 30, 128)        │        13,952 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 30, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 30, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 208,245 (813.46 KB)
#  Trainable params: 208,245 (813.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])
train_model = model.fit(X_train, y_train, epochs=100, callbacks=[
                        checkpoint], validation_data=(X_test, y_test))

plt.plot(train_model.history['categorical_accuracy'])
plt.plot(train_model.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

plt.plot(train_model.history['loss'])
plt.plot(train_model.history['val_loss'])
plt.title('model loss')

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

model.summary()
# Out:
# Epoch 1/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.2691 - loss: 1.6134
# Epoch 1: categorical_accuracy improved from -inf to 0.24762, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 355ms/step - categorical_accuracy: 0.2605 - loss: 1.6122 - val_categorical_accuracy: 0.3556 - val_loss: 1.5510
# Epoch 2/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - categorical_accuracy: 0.2066 - loss: 1.5709
# Epoch 2: categorical_accuracy did not improve from 0.24762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.2078 - loss: 1.5755 - val_categorical_accuracy: 0.7778 - val_loss: 1.4911
# Epoch 3/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.2483 - loss: 1.5632
# Epoch 3: categorical_accuracy improved from 0.24762 to 0.31429, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.2747 - loss: 1.5524 - val_categorical_accuracy: 0.6667 - val_loss: 1.4240
# Epoch 4/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.3785 - loss: 1.4719
# Epoch 4: categorical_accuracy improved from 0.31429 to 0.38095, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - categorical_accuracy: 0.3795 - loss: 1.4672 - val_categorical_accuracy: 0.7333 - val_loss: 1.3792
# Epoch 5/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.3993 - loss: 1.4017
# Epoch 5: categorical_accuracy improved from 0.38095 to 0.40952, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.4034 - loss: 1.4059 - val_categorical_accuracy: 0.7556 - val_loss: 1.2965
# Epoch 6/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.4601 - loss: 1.3012
# Epoch 6: categorical_accuracy improved from 0.40952 to 0.51429, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - categorical_accuracy: 0.4818 - loss: 1.2904 - val_categorical_accuracy: 0.6889 - val_loss: 1.2176
# Epoch 7/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.5330 - loss: 1.2654
# Epoch 7: categorical_accuracy improved from 0.51429 to 0.56190, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.5446 - loss: 1.2562 - val_categorical_accuracy: 0.6667 - val_loss: 1.1308
# Epoch 8/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.6007 - loss: 1.1861
# Epoch 8: categorical_accuracy did not improve from 0.56190
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5814 - loss: 1.2035 - val_categorical_accuracy: 0.5556 - val_loss: 1.0812
# Epoch 9/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.5017 - loss: 1.2392
# Epoch 9: categorical_accuracy did not improve from 0.56190
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.4953 - loss: 1.2349 - val_categorical_accuracy: 0.5111 - val_loss: 1.0492
# Epoch 10/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.5312 - loss: 1.0823
# Epoch 10: categorical_accuracy did not improve from 0.56190
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5168 - loss: 1.1019 - val_categorical_accuracy: 0.4889 - val_loss: 1.0372
# Epoch 11/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.5399 - loss: 1.1527
# Epoch 11: categorical_accuracy improved from 0.56190 to 0.59048, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.5601 - loss: 1.1296 - val_categorical_accuracy: 0.5111 - val_loss: 0.9741
# Epoch 12/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.6094 - loss: 0.9777
# Epoch 12: categorical_accuracy did not improve from 0.59048
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5980 - loss: 0.9926 - val_categorical_accuracy: 0.4889 - val_loss: 0.9588
# Epoch 13/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.5694 - loss: 1.0573
# Epoch 13: categorical_accuracy improved from 0.59048 to 0.61905, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.5893 - loss: 1.0134 - val_categorical_accuracy: 0.4667 - val_loss: 0.9211
# Epoch 14/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.6806 - loss: 0.9336
# Epoch 14: categorical_accuracy did not improve from 0.61905
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6560 - loss: 0.9340 - val_categorical_accuracy: 0.7556 - val_loss: 0.8381
# Epoch 15/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.6042 - loss: 0.9585
# Epoch 15: categorical_accuracy did not improve from 0.61905
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.6101 - loss: 0.9342 - val_categorical_accuracy: 0.8000 - val_loss: 0.8094
# Epoch 16/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.5938 - loss: 1.0072
# Epoch 16: categorical_accuracy did not improve from 0.61905
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5962 - loss: 1.0037 - val_categorical_accuracy: 0.8000 - val_loss: 0.7565
# Epoch 17/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.5868 - loss: 0.9570
# Epoch 17: categorical_accuracy did not improve from 0.61905
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.5768 - loss: 0.9778 - val_categorical_accuracy: 0.7556 - val_loss: 0.7880
# Epoch 18/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.7882 - loss: 0.7174
# Epoch 18: categorical_accuracy improved from 0.61905 to 0.73333, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.7663 - loss: 0.7352 - val_categorical_accuracy: 0.8000 - val_loss: 0.6962
# Epoch 19/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7413 - loss: 0.6752
# Epoch 19: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7191 - loss: 0.7175 - val_categorical_accuracy: 0.7556 - val_loss: 0.7728
# Epoch 20/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.6163 - loss: 0.9386
# Epoch 20: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6022 - loss: 0.9216 - val_categorical_accuracy: 0.6444 - val_loss: 0.7902
# Epoch 21/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7500 - loss: 0.7456
# Epoch 21: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.7281 - loss: 0.7625 - val_categorical_accuracy: 0.7333 - val_loss: 0.8955
# Epoch 22/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.6024 - loss: 0.9232
# Epoch 22: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.6205 - loss: 0.8772 - val_categorical_accuracy: 0.7778 - val_loss: 0.7036
# Epoch 23/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.6840 - loss: 0.8009
# Epoch 23: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.6847 - loss: 0.7846 - val_categorical_accuracy: 0.7778 - val_loss: 0.6614
# Epoch 24/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.6753 - loss: 0.7111
# Epoch 24: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.6719 - loss: 0.7363 - val_categorical_accuracy: 0.8000 - val_loss: 0.6005
# Epoch 25/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.6875 - loss: 0.7797
# Epoch 25: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.6982 - loss: 0.7655 - val_categorical_accuracy: 0.8667 - val_loss: 0.5823
# Epoch 26/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.6580 - loss: 0.8310
# Epoch 26: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.6538 - loss: 0.8150 - val_categorical_accuracy: 0.8000 - val_loss: 0.5666
# Epoch 27/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.7188 - loss: 0.6145
# Epoch 27: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.7208 - loss: 0.6478 - val_categorical_accuracy: 0.8000 - val_loss: 0.5580
# Epoch 28/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.7396 - loss: 0.7739
# Epoch 28: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7295 - loss: 0.7744 - val_categorical_accuracy: 0.8000 - val_loss: 0.5391
# Epoch 29/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - categorical_accuracy: 0.7517 - loss: 0.6236
# Epoch 29: categorical_accuracy did not improve from 0.73333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.7368 - loss: 0.6475 - val_categorical_accuracy: 0.8000 - val_loss: 0.5200
# Epoch 30/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.7465 - loss: 0.6448
# Epoch 30: categorical_accuracy improved from 0.73333 to 0.75238, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.7489 - loss: 0.6400 - val_categorical_accuracy: 0.8000 - val_loss: 0.5216
# Epoch 31/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.7309 - loss: 0.7220
# Epoch 31: categorical_accuracy did not improve from 0.75238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7243 - loss: 0.7179 - val_categorical_accuracy: 0.7778 - val_loss: 0.5535
# Epoch 32/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - categorical_accuracy: 0.6840 - loss: 0.6899
# Epoch 32: categorical_accuracy did not improve from 0.75238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.6923 - loss: 0.6838 - val_categorical_accuracy: 0.7778 - val_loss: 0.5484
# Epoch 33/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.7240 - loss: 0.6382
# Epoch 33: categorical_accuracy did not improve from 0.75238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7010 - loss: 0.6712 - val_categorical_accuracy: 0.8000 - val_loss: 0.4833
# Epoch 34/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.7517 - loss: 0.6564
# Epoch 34: categorical_accuracy improved from 0.75238 to 0.76190, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - categorical_accuracy: 0.7558 - loss: 0.6556 - val_categorical_accuracy: 0.8222 - val_loss: 0.4586
# Epoch 35/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.7448 - loss: 0.6604
# Epoch 35: categorical_accuracy did not improve from 0.76190
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.7364 - loss: 0.6437 - val_categorical_accuracy: 0.8222 - val_loss: 0.4512
# Epoch 36/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - categorical_accuracy: 0.7014 - loss: 0.6913
# Epoch 36: categorical_accuracy did not improve from 0.76190
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.7142 - loss: 0.6622 - val_categorical_accuracy: 0.8000 - val_loss: 0.4512
# Epoch 37/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - categorical_accuracy: 0.7674 - loss: 0.6042
# Epoch 37: categorical_accuracy improved from 0.76190 to 0.77143, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.7690 - loss: 0.6056 - val_categorical_accuracy: 0.8222 - val_loss: 0.4565
# Epoch 38/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.6892 - loss: 0.7373
# Epoch 38: categorical_accuracy did not improve from 0.77143
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.6954 - loss: 0.7160 - val_categorical_accuracy: 0.8444 - val_loss: 0.4570
# Epoch 39/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.7795 - loss: 0.5314
# Epoch 39: categorical_accuracy did not improve from 0.77143
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.7687 - loss: 0.5636 - val_categorical_accuracy: 0.8444 - val_loss: 0.4558
# Epoch 40/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.7604 - loss: 0.6333
# Epoch 40: categorical_accuracy improved from 0.77143 to 0.79048, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - categorical_accuracy: 0.7724 - loss: 0.6138 - val_categorical_accuracy: 0.8444 - val_loss: 0.4567
# Epoch 41/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.7396 - loss: 0.5048
# Epoch 41: categorical_accuracy did not improve from 0.79048
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7485 - loss: 0.5070 - val_categorical_accuracy: 0.8444 - val_loss: 0.4563
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.7857 - loss: 0.6566
# Epoch 42: categorical_accuracy improved from 0.79048 to 0.80952, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - categorical_accuracy: 0.
100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.8889 - loss: 0.3121
# Epoch 82: categorical_accuracy did not improve from 0.90476
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.8762 - loss: 0.3347 - val_categorical_accuracy: 0.9333 - val_loss: 0.5690
# Epoch 83/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.9462 - loss: 0.2994
# Epoch 83: categorical_accuracy improved from 0.90476 to 0.91429, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 0.9334 - loss: 0.3161 - val_categorical_accuracy: 0.8667 - val_loss: 0.5633
# Epoch 84/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.8698 - loss: 0.3236
# Epoch 84: categorical_accuracy did not improve from 0.91429
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8724 - loss: 0.3248 - val_categorical_accuracy: 0.9333 - val_loss: 0.5474
# Epoch 85/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.8733 - loss: 0.3477
# Epoch 85: categorical_accuracy did not improve from 0.91429
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8668 - loss: 0.3533 - val_categorical_accuracy: 0.9111 - val_loss: 0.7059
# Epoch 86/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.9392 - loss: 0.2727
# Epoch 86: categorical_accuracy improved from 0.91429 to 0.93333, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - categorical_accuracy: 0.9369 - loss: 0.2911 - val_categorical_accuracy: 0.9111 - val_loss: 0.7371
# Epoch 87/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.9392 - loss: 0.2730
# Epoch 87: categorical_accuracy did not improve from 0.93333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9254 - loss: 0.2865 - val_categorical_accuracy: 0.9111 - val_loss: 0.7242
# Epoch 88/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.9097 - loss: 0.2839
# Epoch 88: categorical_accuracy did not improve from 0.93333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9115 - loss: 0.2768 - val_categorical_accuracy: 0.9556 - val_loss: 0.3418
# Epoch 89/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.8924 - loss: 0.4143
# Epoch 89: categorical_accuracy did not improve from 0.93333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.8973 - loss: 0.4031 - val_categorical_accuracy: 0.9556 - val_loss: 0.3250
# Epoch 90/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.8819 - loss: 0.4424
# Epoch 90: categorical_accuracy did not improve from 0.93333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.8796 - loss: 0.4414 - val_categorical_accuracy: 0.9556 - val_loss: 0.3188
# Epoch 91/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.9288 - loss: 0.2636
# Epoch 91: categorical_accuracy did not improve from 0.93333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.9192 - loss: 0.2769 - val_categorical_accuracy: 0.9556 - val_loss: 0.3370
# Epoch 92/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9392 - loss: 0.2788
# Epoch 92: categorical_accuracy did not improve from 0.93333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.9369 - loss: 0.3090 - val_categorical_accuracy: 0.9556 - val_loss: 0.3493
# Epoch 93/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.9757 - loss: 0.2189
# Epoch 93: categorical_accuracy improved from 0.93333 to 0.95238, saving model to agung.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.9664 - loss: 0.2369 - val_categorical_accuracy: 0.9556 - val_loss: 0.3302
# Epoch 94/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.9566 - loss: 0.2728
# Epoch 94: categorical_accuracy did not improve from 0.95238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.9473 - loss: 0.2720 - val_categorical_accuracy: 0.9556 - val_loss: 0.3457
# Epoch 95/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.8976 - loss: 0.4132
# Epoch 95: categorical_accuracy did not improve from 0.95238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.9004 - loss: 0.3915 - val_categorical_accuracy: 0.9333 - val_loss: 0.5046
# Epoch 96/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.9062 - loss: 0.2941
# Epoch 96: categorical_accuracy did not improve from 0.95238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.9095 - loss: 0.2877 - val_categorical_accuracy: 0.8889 - val_loss: 0.8143
# Epoch 97/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9167 - loss: 0.2777
# Epoch 97: categorical_accuracy did not improve from 0.95238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.9119 - loss: 0.3103 - val_categorical_accuracy: 0.9111 - val_loss: 0.6866
# Epoch 98/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.9219 - loss: 0.3007
# Epoch 98: categorical_accuracy did not improve from 0.95238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.9226 - loss: 0.2779 - val_categorical_accuracy: 0.9556 - val_loss: 0.3368
# Epoch 99/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.9097 - loss: 0.3581
# Epoch 99: categorical_accuracy did not improve from 0.95238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9039 - loss: 0.3395 - val_categorical_accuracy: 0.9333 - val_loss: 0.5250
# Epoch 100/100
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.9566 - loss: 0.2367
# Epoch 100: categorical_accuracy did not improve from 0.95238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.9549 - loss: 0.2403 - val_categorical_accuracy: 0.9111 - val_loss: 0.7011
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 30, 128)        │        13,952 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 30, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 30, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 624,737 (2.38 MB)
#  Trainable params: 208,245 (813.46 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 416,492 (1.59 MB)

# %%
# plot_model(model, to_file="model1.png", show_shapes=True)

# %% [markdown]
# # **Save Weights**

# %%
number_of_classes = len(actions)
current_date = '10042024'  # changes manually
version = 1

model_filename = "model/model_" + \
    str(number_of_classes) + '_' + 'lstm' + '_' + \
    current_date + '_' + str(version) + ".h5"

print(model_filename)

model.save(model_filename)
model.load_weights(model_filename)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model/model_5_lstm_10042024_1.h5

# %% [markdown]
# # **Evaluation using Confusion Matrix and Accuracy**

# %%
yhat = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step

# %%
print(actions[np.argmax(yhat[2])])
print(actions[np.argmax(y_test[2])])
# Out:
# Mundur
# Mundur

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
from sklearn.metrics import classification_report

report = classification_report(ytrue, yhat, target_names=actions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Kanan       0.87      1.00      0.93        13
#         Maju       1.00      0.78      0.88         9
#         Stop       1.00      0.80      0.89        10
#       Mundur       1.00      1.00      1.00         4
#         Kiri       0.82      1.00      0.90         9
#
#     accuracy                           0.91        45
#    macro avg       0.94      0.92      0.92        45
# weighted avg       0.93      0.91      0.91        45

# %%
# mcm = multilabel_confusion_matrix(ytrue, yhat)
# print(mcm)

# %%
ytrue = np.argmax(y_test, axis=1)
conf_matrix = confusion_matrix(ytrue, yhat)

plt.figure(figsize=(10, 8))
heatMap = sns.heatmap(conf_matrix, annot=True, fmt='d',
                      cmap='Blues', xticklabels=actions, yticklabels=actions)

heatMap.set_xlabel('Predicted Label', labelpad=30, weight='bold')
heatMap.set_ylabel('True Label', labelpad=30, weight='bold')

heatMap.set_title('Confusion Matrix', pad=20, weight='bold', fontsize=20)
plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support

metrics = precision_recall_fscore_support(ytrue, yhat)

precision_per_class = metrics[0]
recall_per_class = metrics[1]
f1_score_per_class = metrics[2]

for i, class_name in enumerate(actions):
    print(f"Class: {class_name}")
    print(f"Precision: {precision_per_class[i]}")
    print(f"Recall: {recall_per_class[i]}")
    print(f"F1 Score: {f1_score_per_class[i]}\n")

accuracy_per_class = [(conf_matrix[i, i] / np.sum(conf_matrix[:, i]))
                      for i in range(len(actions))]

for i, class_name in enumerate(actions):
    print(f"Class: {class_name}")
    print(f"Accuracy: {accuracy_per_class[i]}\n")
# Out:
# Class: Kanan
# Precision: 0.8666666666666667
# Recall: 1.0
# F1 Score: 0.9285714285714286
#
# Class: Maju
# Precision: 1.0
# Recall: 0.7777777777777778
# F1 Score: 0.875
#
# Class: Stop
# Precision: 1.0
# Recall: 0.8
# F1 Score: 0.8888888888888888
#
# Class: Mundur
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# Class: Kiri
# Precision: 0.8181818181818182
# Recall: 1.0
# F1 Score: 0.9
#
# Class: Kanan
# Accuracy: 0.8666666666666667
#
# Class: Maju
# Accuracy: 1.0
#
# Class: Stop
# Accuracy: 1.0
#
# Class: Mundur
# Accuracy: 1.0
#
# Class: Kiri
# Accuracy: 0.8181818181818182
